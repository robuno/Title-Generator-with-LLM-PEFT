# %%
import os
import pandas as pd

# %%
df_results = pd.read_csv('./output/bart_6000_cs_abs_test_results_2.csv')
df_results.head()
# Out:
#    Unnamed: 0                                              label  \
# 0           0  Quantum circuits for strongly correlated quant...
# 1           1  Early Warnings of Cyber Threats in Online Disc...
# 2           2  Evaluation of Plane Detection with RANSAC Acco...
# 3           3  TeKo: Text-Rich Graph Neural Networks with Ext...
# 4           4  Multiparty Compatibility in Communicating Auto...
#
#                                           prediction
# 0  Quantum Simulation of strongly correlated Many...
# 1  Generate alerts of imminent or current cyber-t...
# 2                            Random Sample Consensus
# 3  Text-rich Graph Neural Networks with External ...
# 4  Multiparty Session Types: Implications for   M...

# %%
df_results['prediction'] = df_results['prediction'].str.replace('Generate a relevant title related to the given abstracte: ', '')
df_results.head()
# Out:
#    Unnamed: 0                                              label  \
# 0           0  Quantum circuits for strongly correlated quant...
# 1           1  Early Warnings of Cyber Threats in Online Disc...
# 2           2  Evaluation of Plane Detection with RANSAC Acco...
# 3           3  TeKo: Text-Rich Graph Neural Networks with Ext...
# 4           4  Multiparty Compatibility in Communicating Auto...
#
#                                           prediction
# 0  Quantum Simulation of strongly correlated Many...
# 1  Generate alerts of imminent or current cyber-t...
# 2                            Random Sample Consensus
# 3  Text-rich Graph Neural Networks with External ...
# 4  Multiparty Session Types: Implications for   M...

# %%
for index, row in df_results.iterrows():
  print(f"[LABEL]:{row['label']}")
  print(f"[PRED]:{row['prediction']}")
  print('-'.join('' for x in range(20)))
# Out:
# [LABEL]:Quantum circuits for strongly correlated quantum systems
# [PRED]:Quantum Simulation of strongly correlated Many-Body Hamiltonians
# -------------------
# [LABEL]:Early Warnings of Cyber Threats in Online Discussions
# [PRED]:Generate alerts of imminent or current cyber-threats
# -------------------
# [LABEL]:Evaluation of Plane Detection with RANSAC According to Density of 3D   Point Clouds
# [PRED]:Random Sample Consensus
# -------------------
# [LABEL]:TeKo: Text-Rich Graph Neural Networks with External Knowledge
# [PRED]:Text-rich Graph Neural Networks with External Knowledge
# -------------------
# [LABEL]:Multiparty Compatibility in Communicating Automata: Characterisation and   Synthesis of Global Session Types
# [PRED]:Multiparty Session Types: Implications for   Multiparty Synchronisation
# -------------------
# [LABEL]:Self-Supervised 3D Traversability Estimation with Proxy Bank Guidance
# [PRED]:Traversability estimation for mobile robots in off-road environments
# -------------------
# [LABEL]:Multi-user Communication Networks: A Coordinated Multi-armed Bandit   Approach
# [PRED]:Multi-Armed Bandit Learning for Multi-User Level Communication Networks
# -------------------
# [LABEL]:Online Dynamic Network Embedding
# [PRED]:Recurrent Neural Network Embedding for Dynamic Networks
# -------------------
# [LABEL]:Analyzing Infrastructure LiDAR Placement with Realistic LiDAR Simulation   Library
# [PRED]:Realistic LiDAR Simulation for Infrastructure Sensors
# -------------------
# [LABEL]:Self-Stabilization: The Implicit Bias of Gradient Descent at the Edge of   Stability
# [PRED]:General Dynamics of gradient descent
# -------------------
# [LABEL]:Game Theory for Cyber Deception: A Tutorial
# [PRED]:Introduction to Game Theory of Deception and Counter-Deception
# -------------------
# [LABEL]:Trustworthy modelling of atmospheric formaldehyde powered by deep   learning
# [PRED]:Deep Learning for Remote Sensing of Formaldehyde in the Atmosphere
# -------------------
# [LABEL]:Combining deep learning and street view imagery to map smallholder crop   types
# [PRED]:Collaborative Agriculture with Deep Learning and Google Street View
# -------------------
# [LABEL]:Designing Trustworthy User Interfaces
# [PRED]:Generate a proof of concept interface for user interface design
# -------------------
# [LABEL]:A Fundamental Performance Limitation for Adversarial Classification
# [PRED]:Generate a relevant title related to the classification of binary classification algorithms
# -------------------
# [LABEL]:A Framework for learning multi-agent dynamic formation strategy in   real-time applications
# [PRED]:Generate a group of algorithms for learning formation strategy in a restricted environment
# -------------------
# [LABEL]:Reduced-Order Modeling of Thermal Dynamics in District Energy Networks   using Spectral Clustering
# [PRED]:Simulation of thermal dynamics in city-scale district energy grids
# -------------------
# [LABEL]:Uncertainty-Aware Text-to-Program for Question Answering on Structured   Electronic Health Records
# [PRED]:Generate a program-based model for EHR-QA
# -------------------
# [LABEL]:Query-Efficient Adversarial Attack Based on Latin Hypercube Sampling
# [PRED]:LHS-BA: A Latin Hypercube Sampling Based Boundary Attack
# -------------------
# [LABEL]:Infinite Unlimited Churn
# [PRED]:Unfair Infinite Unlimited Churn Problem in Peer-to-Peer overlay Networks
# -------------------
# [LABEL]:Two-stage WECC Composite Load Modeling: A Double Deep Q-Learning   Networks Approach
# [PRED]:Double Deep Q-Learning Network for the WECC CLM
# -------------------
# [LABEL]:The Hodge Laplacian on Axisymmetric Domains and its Discretization
# [PRED]:Fourer-finite-element-methods in weighted functions spaces
# -------------------
# [LABEL]:CARGO: Effective format-free compressed storage of genomic information
# [PRED]:CARGO: Compressed ARchiving for GenOmics
# -------------------
# [LABEL]:Music-to-Text Synaesthesia: Generating Descriptive Text from Music   Recordings
# [PRED]:music-to-text synaesthesia
# -------------------
# [LABEL]:diagnoseIT: Expertengest\"utzte automatische Diagnose von   Performance-Probleme in Enterprise-Anwendungen (Abschlussbericht)
# [PRED]:This is the final report of the collaborative research project diagnoseIT on expert-guided automatic diagnosis of performance problems in enterprise applications.
# -------------------
# [LABEL]:XGBoost energy consumption prediction based on multi-system data HVAC
# [PRED]:Generate an efficient energy consumption prediction model for the Internet of Things platform
# -------------------
# [LABEL]:Randomized Projection Methods for Linear Systems with Arbitrarily Large   Sparse Corruptions
# [PRED]:Large-scale linear equations
# -------------------
# [LABEL]:Automatic Identification of Stone-Handling Behaviour in Japanese   Macaques Using LabGym Artificial Intelligence
# [PRED]:Artificial Intelligence for the Analysis of   Primate Behaviour
# -------------------
# [LABEL]:Electrocorticographic Dynamics Predict Visually Guided Motor Imagery of   Grasp Shaping
# [PRED]:Figure 1: Neural dynamics of hand grasp shaping in volitional neuroprosthetics
# -------------------
# [LABEL]:Proactive Resilient Transmission and Scheduling Mechanisms for mmWave   Networks
# [PRED]:Risk to Link Failures in mmWave Networks
# -------------------
# [LABEL]:Energy-Efficient Power Control of Train-ground mmWave Communication for   High Speed Trains
# [PRED]:Energy Efficiency of train-ground mmWave communication for high speed trains
# -------------------
# [LABEL]:Quaternion-based non-singular terminal sliding mode control for a   satellite-mounted space manipulator
# [PRED]:A robust control solution for a satellite equipped with a robotic manipulator
# -------------------
# [LABEL]:The Big-O Problem
# [PRED]:Generated Title: The Big-O Problem for Unlabelled Weighted Automata
# -------------------
# [LABEL]:Who Goes First? Influences of Human-AI Workflow on Decision Making in   Clinical Imaging
# [PRED]:Introduction to Human-AI Collaboration
# -------------------
# [LABEL]:Multi-stream Convolutional Neural Network with Frequency Selection for   Robust Speaker Verification
# [PRED]:Multi-stream Convolutional Neural Network for Speaker Verification
# -------------------
# [LABEL]:Tableau-based procedure for deciding satisfiability in the full   coalitional multiagent epistemic logic
# [PRED]:Generate a relevant title related to the multiagent epistemic logic CMAELCD
# -------------------
# [LABEL]:Physics-guided Deep Markov Models for Learning Nonlinear Dynamical   Systems with Uncertainty
# [PRED]:A probabilistic physics-guided Deep Markov Model for Nonlinear Dynamical Systems
# -------------------
# [LABEL]:A penalty scheme for monotone systems with interconnected obstacles:   convergence and error estimates
# [PRED]:Penalty approach for quasi-variational inequalities
# -------------------
# [LABEL]:Safe Approximate Dynamic Programming Via Kernelized Lipschitz Estimation
# [PRED]:Generate safe initial policies for reinforcement learning via approximate dynamic programming
# -------------------
# [LABEL]:Evaluating Gradient Inversion Attacks and Defenses in Federated Learning
# [PRED]:Gradient inversion attack: a new defense mechanism for Federated Learning
# -------------------
# [LABEL]:Massively Parallel Algorithms for the Lattice Boltzmann Method on   Non-uniform Grids
# [PRED]:Lattice Boltzmann-Based Simulation on Non-Uniform grids
# -------------------
# [LABEL]:New Confocal Hyperbola-based Ellipse Fitting with Applications to   Estimating Parameters of Mechanical Pipes from Point Clouds
# [PRED]:Interpretation of the confocal hyperbola approximation to the geometric distance of cylindrical mechanical pipes from point clouds
# -------------------
# [LABEL]:SC-Block: Supervised Contrastive Blocking within Entity Resolution   Pipelines
# [PRED]:Contextual Contrastive Learning for Blocker Resolution
# -------------------
# [LABEL]:Application of Zone Method based Machine Learning and Physics-Informed   Neural Networks in Reheating Furnaces
# [PRED]:Generate Data for Reheating Furnaces in Foundation Industries
# -------------------
# [LABEL]:Digital Metasurface Based on Graphene: An Application to Beam Steering   in Terahertz Plasmonic Antennas
# [PRED]:Metasurfaces: A Design Approach to Reconfigurable and   Programmability
# -------------------
# [LABEL]:Measuring the Effectiveness of Privacy Policies for Voice Assistant   Applications
# [PRED]:Privacy Policies on Voice Assistants and Google Assistant
# -------------------
# [LABEL]:A survey on bias in machine learning research
# [PRED]:Understanding the sources and consequences of bias in machine learning
# -------------------
# [LABEL]:Curriculum Learning for Compositional Visual Reasoning
# [PRED]:Visual Question Answering
# -------------------
# [LABEL]:A Note on Easy and Efficient Computation of Full Abelian Periods of a   Word
# [PRED]:Constantinescu and Ilie
# -------------------
# [LABEL]:SA-UNet: Spatial Attention U-Net for Retinal Vessel Segmentation
# [PRED]:Spatial Attention U-Net: Spatial Attention for Eye-related Diseases
# -------------------
# [LABEL]:The Approximation Ratio of the Greedy Algorithm for the Metric Traveling   Salesman Problem
# [PRED]:We prove the approximation ratio of the Clarke-Wright savings heuristic for the metric Traveling Salesman Problem is $\The
# -------------------
# [LABEL]:Collaborative Unsupervised Visual Representation Learning from   Decentralized Data
# [PRED]:Federated Unsupervised Image Learning
# -------------------
# [LABEL]:Benchmarking the face-centred finite volume method for compressible   laminar flows
# [PRED]:Generate numerical benchmarks for compressible laminar flows using face-centred finite volume software
# -------------------
# [LABEL]:Anticipatory Buffer Control and Quality Selection for Wireless Video   Streaming
# [PRED]:Generate a practical heuristic for segmented video streaming protocols
# -------------------
# [LABEL]:Fused Gromov-Wasserstein distance for structured objects: theoretical   foundations and mathematical properties
# [PRED]:Generate a relevant title related to the Fused Gromov-Wasserstein Distance
# -------------------
# [LABEL]:Deep learning-based survival prediction for multiple cancer types using   histopathology images
# [PRED]:DLS to Predict Disease Specific Survival across 10 Cancer Types from The Cancer Genome Atlas
# -------------------
# [LABEL]:Decomposition Complexity
# [PRED]:Generate a relevant title related to the problem of decomposition of a ternary function into binary ones
# -------------------
# [LABEL]:Tactile Image-to-Image Disentanglement of Contact Geometry from   Motion-Induced Shear
# [PRED]:Generate a supervised convolutional deep neural network model for soft optical tactile sensors
# -------------------
# [LABEL]:On Finding the Largest Mean Among Many
# [PRED]:Best Arm Sampling in a Multi-armed Bandit Problem
# -------------------
# [LABEL]:Cleanformer: A multichannel array configuration-invariant neural   enhancement frontend for ASR in smart speakers
# [PRED]:Cleanformer, a multichannel neural based enhancement frontend for automatic speech recognition
# -------------------
# [LABEL]:TS-Reconfiguration of Dominating Sets in circle and circular-arc graphs
# [PRED]:Generate a relevant title related to the dominating set reconfiguration problem with token sliding rule
# -------------------
# [LABEL]:Unifying Heterogeneous Classifiers with Distillation
# [PRED]:Unifying Heterogeneous Classifiers
# -------------------
# [LABEL]:Safe Control under Uncertainty
# [PRED]:Probabilistic Signal Temporal Logic for Hybrid Systems
# -------------------
# [LABEL]:Meta-Learning with Less Forgetting on Large-Scale Non-Stationary Task   Distributions
# [PRED]:Semi-Supervised Meta-Learning with Evolving Task DiStributions
# -------------------
# [LABEL]:Adaptive Visualisation System for Construction Building Information   Models Using Saliency
# [PRED]:Building Information Modeling
# -------------------
# [LABEL]:A new heuristic algorithm for fast k-segmentation
# [PRED]:A novel heuristic algorithm for $k$-segmentation
# -------------------
# [LABEL]:Implementation paradigm for supervised flare forecasting studies: a deep   learning application with video data
# [PRED]:Generate a general paradigm for Solar Flare Forecasting
# -------------------
# [LABEL]:Initialization of Latent Space Coordinates via Random Linear Projections   for Learning Robotic Sensory-Motor Sequences
# [PRED]:Generative model for robot sensory-motor behaviour primitives
# -------------------
# [LABEL]:Population and Inequality Dynamics in Simple Economies
# [PRED]:Generate a relevant title related to the complexity of complex population and inequality dynamics in biology and ecology
# -------------------
# [LABEL]:Cyber-Physical Security and Safety of Autonomous Connected Vehicles:   Optimal Control Meets Multi-Armed Bandit Learning
# [PRED]:An optimal safe controller for Autonomous Connected Vehicles
# -------------------
# [LABEL]:The Narayana Universal Code
# [PRED]:This paper presents a method of universal coding based on the Narayana series
# -------------------
# [LABEL]:Subset Selection Based On Multiple Rankings in the Presence of Bias:   Effectiveness of Fairness Constraints for Multiwinner Voting Score Functions
# [PRED]:Smoothness of Submodular Score Functions for subset Selection
# -------------------
# [LABEL]:Radio Localization and Sensing -- Part II: State-of-the-art and   Challenges
# [PRED]:5G and 5G
# -------------------
# [LABEL]:Security Support in Continuous Deployment Pipeline
# [PRED]:Generate a relevant abstract related to the security tactics of Continuous Deployment Pipeline (CD)
# -------------------
# [LABEL]:PCA Initialization for Approximate Message Passing in Rotationally   Invariant Models
# [PRED]:Approximate Message Passing (AMP) with Principal Component Analysis
# -------------------
# [LABEL]:A Monaural Speech Enhancement Method for Robust Small-Footprint Keyword   Spotting
# [PRED]:Generate a Convolutional Neural Networks based KWS System
# -------------------
# [LABEL]:Policy-Induced Self-Supervision Improves Representation Finetuning in   Visual RL
# [PRED]:Generate a self-supervised objective for representation pretrained on source tasks in visual percept based RL
# -------------------
# [LABEL]:Enforcing Linearity in DNN succours Robustness and Adversarial Image   Generation
# [PRED]:Generating adversarial image generation using Inverse Representation Learning and Local Lipschitz Regularizer
# -------------------
# [LABEL]:Using Small Proxy Datasets to Accelerate Hyperparameter Search
# [PRED]:Proxy Datasets for Machine Learning
# -------------------
# [LABEL]:Semantic Segmentation of Legal Documents via Rhetorical Roles
# [PRED]:Generate a corpus of legal documents with three semantically coherent units labels (referred to as Rhetorical Roles)
# -------------------
# [LABEL]:Two New Approaches to Optical IRSs: Schemes and Comparative Analysis
# [PRED]:Generate a relevant title related to the point-to-multipoint free space optical communication (FSO) scenarios
# -------------------
# [LABEL]:Providing an Object Allocation Algorithm in Distributed Databases Using   Efficient Factors
# [PRED]:Data replication in distributed database systems
# -------------------
# [LABEL]:Runtime Monitoring of Dynamic Fairness Properties
# [PRED]:Monitoring Fairness in Static Decision-Making
# -------------------
# [LABEL]:Fast, Smart Neuromorphic Sensors Based on Heterogeneous Networks and   Mixed Encodings
# [PRED]:Neuromorphic architectures for smart sensors
# -------------------
# [LABEL]:Progression and Challenges of IoT in Healthcare: A Short Review
# [PRED]:Smart Healthcare and Healthcare: A Comparative Analysis of Smart Healthcare and   Security
# -------------------
# [LABEL]:Boosting Neural Networks to Decompile Optimized Binaries
# [PRED]:NeurDP: Neural Machine Translation in Natural Language Processing
# -------------------
# [LABEL]:Towards Natural Language-Guided Drones: GeoText-1652 Benchmark with   Spatially Relation Matching
# [PRED]:Generate a Natural Language-Based Dataset for Drone Navigation Through   Natural Language   Commands
# -------------------
# [LABEL]:Generalized Matrix Means for Semi-Supervised Learning with Multilayer   Graphs
# [PRED]:Semi-supervised learning on multilayer graphs
# -------------------
# [LABEL]:Frequency Gating: Improved Convolutional Neural Networks for Speech   Enhancement in the Time-Frequency Domain
# [PRED]:Frequency Gating for Convolutional Neural Networks
# -------------------
# [LABEL]:Similarity based Dynamic Web Data Extraction and Integration System from   Search Engine Result Pages for Web Content Mining
# [PRED]:WDES and WDICS
# -------------------
# [LABEL]:Predicting Economic Development using Geolocated Wikipedia Articles
# [PRED]:nan
# -------------------
# [LABEL]:Decomposing Counterfactual Explanations for Consequential Decision   Making
# [PRED]:DisEntangling Algorithmic Recourses
# -------------------
# [LABEL]:Choice by Elimination via Deep Neural Networks
# [PRED]:Generate a relevant title related to the concept of Neural Choice by Elimination
# -------------------
# [LABEL]:On Training Robust PDF Malware Classifiers
# [PRED]:State-of-the-art PDF malware classifiers with verifiable robustness properties
# -------------------
# [LABEL]:Leveraging Knowledge and Reinforcement Learning for Enhanced Reliability   of Language Models
# [PRED]:Learning-guided Learning of General Language Understanding and Evaluation (GLUE)
# -------------------
# [LABEL]:Dropout as data augmentation
# [PRED]:Generate a new dropout noise scheme based on our observations and data augmentation
# -------------------
# [LABEL]:Consistent discretization of finite/fixed-time controllers
# [PRED]:Discretization of a homogeneous homogeneous control
# -------------------
# [LABEL]:GNNInterpreter: A Probabilistic Generative Model-Level Explanation for   Graph Neural Networks
# [PRED]:Generate a model-agnostic model-level explanation for Graph Neural Networks
# -------------------
# [LABEL]:An Auxiliary Space Preconditioner for Fractional Laplacian of Negative   Order
# [PRED]:Coupled Multiphysics Problems
# -------------------
# [LABEL]:Optimizing Hybrid Spreading in Metapopulations
# [PRED]:The optimum balance between hybrid epidemics and global spreading
# -------------------
# [LABEL]:Large Language Models are not Fair Evaluators
# [PRED]:Calibration for Large Language Models
# -------------------
# [LABEL]:An Attention-Based Denoising Framework for Personality Detection in   Social Media Texts
# [PRED]:Attention-Based Information Extracting for Personality Detection
# -------------------
# [LABEL]:FVC: A New Framework towards Deep Video Compression in Feature Space
# [PRED]:Feature-space Video Compression for Learning Based Video Coding
# -------------------
# [LABEL]:Spatial Networks
# [PRED]:Generate a relevant title related to the structure and the evolution of spatial networks
# -------------------
# [LABEL]:Fairness in Streaming Submodular Maximization: Algorithms and Hardness
# [PRED]:Fair Machine Learning for Massive Datapoints
# -------------------
# [LABEL]:Retrieval-Free Knowledge-Grounded Dialogue Response Generation with   Adapters
# [PRED]:KnowExpert: A framework to bypass the explicit retrieval process in knowledge-grounded dialogue
# -------------------
# [LABEL]:Demonstration-efficient Inverse Reinforcement Learning in Procedurally   Generated Environments
# [PRED]:Adversarial Inverse Reinforcement Learning
# -------------------
# [LABEL]:Solving Elliptic Equations with Brownian Motion: Bias Reduction and   Temporal Difference Learning
# [PRED]:Generate a Feynman-Kac formula for elliptic partial differential equations in terms of expectations of continuous time Markov processes
# -------------------
# [LABEL]:Unsuitability of NOTEARS for Causal Graph Discovery
# [PRED]:Causal Discovery Methods
# -------------------
# [LABEL]:Dynamic Planar Convex Hull
# [PRED]:Generate a relevant abstract for the amortized computational complexity of planar dynamic convex hull problem by querying
# -------------------
# [LABEL]:Uncertainty-Aware CNNs for Depth Completion: Uncertainty from Beginning   to End
# [PRED]:Uncertainty of depth data in depth completion
# -------------------
# [LABEL]:A Birds Eye View on Knowledge Graph Embeddings, Software Libraries,   Applications and Challenges
# [PRED]:Generate a relevant title related to Knowledge Graph Completion
# -------------------
# [LABEL]:Expression-preserving face frontalization improves visually assisted   speech processing
# [PRED]:Facefrontalization for Visual Assistant Speech Communication
# -------------------
# [LABEL]:Inducing Honest Reporting Without Observing Outcomes: An Application to   the Peer-Review Process
# [PRED]:Generate a scoring method to induce honest reporting in the peer-review process
# -------------------
# [LABEL]:Lila: A Unified Benchmark for Mathematical Reasoning
# [PRED]:LILA: A Unified Mathematical Reasoning Benchmark for AI
# -------------------
# [LABEL]:A Graph Symmetrisation Bound on Channel Information Leakage under   Blowfish Privacy
# [PRED]:Blowfish privacy in communications theory
# -------------------
# [LABEL]:Topics to Avoid: Demoting Latent Confounds in Text Classification
# [PRED]:in the context of native language identification
# -------------------
# [LABEL]:Accelerating System Adequacy Assessment using the Multilevel Monte Carlo   Approach
# [PRED]:Generate a relevant title related to the Multilevel Monte Carlo framework
# -------------------
# [LABEL]:Distributed Bandits with Heterogeneous Agents
# [PRED]:A Multi-Agent Bandit Setting with Two Learning Algorithms
# -------------------
# [LABEL]:From Regular to Context Free to Mildly Context Sensitive Tree Rewriting   Systems: The Path of Child Language Acquisition
# [PRED]:The genesis of complex sentences
# -------------------
# [LABEL]:Applying unsupervised keyphrase methods on concepts extracted from   discharge sheets
# [PRED]:Generate essential phrase methods for clinical notes
# -------------------
# [LABEL]:Testing Preferential Domains Using Sampling
# [PRED]:A preferential domain
# -------------------
# [LABEL]:Key-phrase boosted unsupervised summary generation for FinTech   organization
# [PRED]:Unsupervised phrase-based summary generation from social media data
# -------------------
# [LABEL]:Encoding Electromagnetic Transformation Laws for Dimensional Reduction
# [PRED]:Generate a relevant title related to Electromagnetic phenomena
# -------------------
# [LABEL]:R-GCN: The R Could Stand for Random
# [PRED]:Random Relational Graph Convolutional Network
# -------------------
# [LABEL]:Provably Precise, Succinct and Efficient Explanations for Decision Trees
# [PRED]:Decision Trees for Decision Trees
# -------------------
# [LABEL]:Transfer-Ensemble Learning based Deep Convolutional Neural Networks for   Diabetic Retinopathy Classification
# [PRED]:An ensemble model for diabetic retinopathy classification using convolutional neural networks
# -------------------
# [LABEL]:Learning to Operate in Open Worlds by Adapting Planning Models
# [PRED]:Reinforcement Learning for Planning Agents in Open Worlds
# -------------------
# [LABEL]:Is $L^2$ Physics-Informed Loss Always Suitable for Training   Physics-Informed Neural Network?
# [PRED]:The Physics-Informed Neural Network (PINN) is a New and promising way to solve partial differential equations using   Deep Learning
# -------------------
# [LABEL]:FL-Market: Trading Private Models in Federated Learning
# [PRED]:FL-Market: A locally private platform for ML-oriented data acquisition
# -------------------
# [LABEL]:Confidence intervals for the random forest generalization error
# [PRED]:Generate a relevant title related to the byproducts of the standard training process of random forest
# -------------------
# [LABEL]:Kernel PCA for multivariate extremes
# [PRED]:Generate a relevant title related to the performance of kernel PCA preimages of multivariate extremes
# -------------------
# [LABEL]:Deep Joint Source-Channel Coding for Wireless Image Retrieval
# [PRED]:Generate a DNN-based Communication Scheme for Image Retrieval Over a Wireless Channel
# -------------------
# [LABEL]:Algorithms on Ideal over Complex Multiplication order
# [PRED]:Generate a relevant title related to the Gentry-Szydlo algorithm for cyclotomic orders
# -------------------
# [LABEL]:Towards a communication-theoretic understanding of system-level power   consumption
# [PRED]:Maximization of Total System Power in Communication Links
# -------------------
# [LABEL]:From Understanding the Population Dynamics of the NSGA-II to the First   Proven Lower Bounds
# [PRED]:Generate a relevant title related to the OneMinMax problem and the OneJumpZeroJump problem
# -------------------
# [LABEL]:High-Order Tensor Recovery with A Tensor $U_1$ Norm
# [PRED]:Tensor Recovery Methods for High-order Tensor Data
# -------------------
# [LABEL]:Mixed Precision DNNs: All you need is a good parametrization
# [PRED]:A mixed precision DNN with learned quantization parameters
# -------------------
# [LABEL]:Quantum-Aided Meta-Learning for Bayesian Binary Neural Networks via Born   Machines
# [PRED]:Near-term noisy intermediate-scale quantum circuits with probabilistic models
# -------------------
# [LABEL]:Pricing-based Distributed Downlink Beamforming in Multi-Cell OFDMA   Networks
# [PRED]:Generate a non-convex optimization problem for multi-cell OFDMA networks
# -------------------
# [LABEL]:What's the Problem, Linda? The Conjunction Fallacy as a Fairness Problem
# [PRED]:Generate a relevant title related to the conjunction fallacy
# -------------------
# [LABEL]:On the convex hull of convex quadratic optimization problems with   indicators
# [PRED]:Convexification of mixed-integer nonlinear sets in an extended formulation
# -------------------
# [LABEL]:Feedback Refined Local-Global Network for Super-Resolution of   Hyperspectral Imagery
# [PRED]:Feedback Refined Local-Global Network for the Super-Resolution of hyperspectral Image
# -------------------
# [LABEL]:Privacy-Preserving Polynomial Computing Over Distributed Data
# [PRED]:Generate a Lagrange encoding approach for polynomial computing over distributed data
# -------------------
# [LABEL]:Performance Evaluation of Stochastic Bipartite Matching Models
# [PRED]:A stochastic bipartite matching model
# -------------------
# [LABEL]:SSIM-Based CTU-Level Joint Optimal Bit Allocation and Rate Distortion   Optimization
# [PRED]:Structural similarity (SSIM)-based distortion of video quality
# -------------------
# [LABEL]:Maximum Likelihood Estimation for Learning Populations of Parameters
# [PRED]:Generate a Minimum likelihood estimator for $N$ independent Bernoulli trials
# -------------------
# [LABEL]:Is Data Clustering in Adversarial Settings Secure?
# [PRED]:Generate a general framework to identify potential attacks against clustering algorithms
# -------------------
# [LABEL]:Merchant Category Identification Using Credit Card Transactions
# [PRED]:Generate a multi-modal learning model for the identification of merchant-merchant relationship
# -------------------
# [LABEL]:Faster and better: a machine learning approach to corner detection
# [PRED]:The Heuristic for Feature Detectors in Real-World Applications
# -------------------
# [LABEL]:A Parallel-In-Time Adjoint Sensitivity Analysis for a B6 Bridge-Motor   Supply Circuit
# [PRED]:Parallel-in-Time adjoint sensitivity analysis with parareal approach
# -------------------
# [LABEL]:The Limit Order Book Recreation Model (LOBRM): An Extended Analysis
# [PRED]:LOBRM: A New Approach to the Limit Order Book for Financial Assets
# -------------------
# [LABEL]:Web Image Context Extraction with Graph Neural Networks and Sentence   Embeddings on the DOM tree
# [PRED]:Web Image Context Extraction
# -------------------
# [LABEL]:Robust Experimentation in the Continuous Time Bandit Problem
# [PRED]:Experimenting the Decision Making Environment in Two-Armed Bandit Setup
# -------------------
# [LABEL]:Normalized gradient flow optimization in the training of ReLU artificial   neural networks
# [PRED]:ReLU ANNs: A Multidimensional Approach to the Training of Artificial Neural Networks
# -------------------
# [LABEL]:AGENT: An Adaptive Grouping Entrapping Method of Flocking Systems
# [PRED]:This study proposes a distributed algorithm for adaptive grouping of multiple targets entrapping
# -------------------
# [LABEL]:TrUMAn: Trope Understanding in Movies and Animations
# [PRED]:Trot Understanding in Movies and Animations (TrUMAn)
# -------------------
# [LABEL]:Deep Reinforcement Learning-Based Long-Range Autonomous Valet Parking   for Smart Cities
# [PRED]:A Long-Range Autonomous Valet Parking Framework for the City Center
# -------------------
# [LABEL]:Augmented unprojected Krylov subspace methods
# [PRED]:Augmented Krylov Subspace Methods for Recurrent Applications
# -------------------
# [LABEL]:Control Synthesis of Nonlinear Sampled Switched Systems using Euler's   Method
# [PRED]:Generate a symbolic control synthesis method for nonlinear sampled switched systems using one-sided Lipschitz
# -------------------
# [LABEL]:Model-based actor-critic: GAN (model generator) + DRL (actor-critic) =>   AGI
# [PRED]:Model-Based DDPG Architecture for AI and Robotics
# -------------------
# [LABEL]:On the Dynamics of Human Proximity for Data Diffusion in Ad-Hoc Networks
# [PRED]:Data-driven investigation of the dynamics of message spreading in a real-world dynamical network of human proximity
# -------------------
# [LABEL]:Efficient Compilation and Mapping of Fixed Function Combinational Logic   onto Digital Signal Processors Targeting Neural Network Inference and   Utilizing High-level Synthesis
# [PRED]:Generate a novel framework for FPGA-based NN inference using fixed function combinational logic
# -------------------
# [LABEL]:Remote Work Optimization with Robust Multi-channel Graph Neural Networks
# [PRED]:Generate a principled approach to the problem of remote workplace   recruitment with limited information
# -------------------
# [LABEL]:HIGhER : Improving instruction following with Hindsight Generation for   Experience Replay
# [PRED]:Hindsight Generation for Experience Replay
# -------------------
# [LABEL]:On coloring parameters of triangle-free planar $(n,m)$-graphs
# [PRED]:A homomorphism of a graph to another graph with adjacencies of $G$ types and directions
# -------------------
# [LABEL]:Training Deep Neural Networks with Joint Quantization and Pruning of   Weights and Activations
# [PRED]:Quantization and pruning for Deep Neural Networks
# -------------------
# [LABEL]:1-bit Adam: Communication Efficient Large-Scale Training with Adam's   Convergence Speed
# [PRED]:Generate a relevant title related to Scalable Training of Large Models
# -------------------
# [LABEL]:The Privacy Funnel from the viewpoint of Local Differential Privacy
# [PRED]:Generate a Data Privacy Model for the Privacy Funnel
# -------------------
# [LABEL]:ASYNC: A Cloud Engine with Asynchrony and History for Distributed   Machine Learning
# [PRED]:ASYNC: A Framework for Asynchrony and History for Machine Learning on   distributed computing platforms
# -------------------
# [LABEL]:Similarity based hierarchical clustering of physiological parameters for   the identification of health states - a feasibility study
# [PRED]:Generate a relevant abstract for the clustering of physiological data into health states based on similarity constraint
# -------------------
# [LABEL]:Sequence Aggregation Rules for Anomaly Detection in Computer Network   Traffic
# [PRED]:Unsupervised anomaly detection for cybersecurity applications on computer network traffic data
# -------------------
# [LABEL]:System Equivalence Transformation: Robust Convergence of Iterative   Learning Control with Nonrepetitive Uncertainties
# [PRED]:Double-dynamics analysis for iterative learning control
# -------------------
# [LABEL]:Changepoint Analysis of Topic Proportions in Temporal Text Data
# [PRED]:In this article, we consider \emph{offline} changepoint detection in large corpora
# -------------------
# [LABEL]:On the Garden of Eden theorem for non-uniform cellular automata
# [PRED]:Generate a relevant title related to the Garden of Eden theorem for non-uniform cellular automata over amenable group universes
# -------------------
# [LABEL]:Weighted Notions of Fairness with Binary Supermodular Chores
# [PRED]:Generate a general framework for fair allocation with binary supermodular cost functions
# -------------------
# [LABEL]:Mass Loss and Displacement Modeling for Multi-Axis Milling
# [PRED]:Generate a model for estimating the mass loss and displacement of the center of mass during multi-axis milling processes
# -------------------
# [LABEL]:Fixed Points in Cyber Space: Rethinking Optimal Evasion Attacks in the   Age of AI-NIDS
# [PRED]:Blackbox adversarial attacks on network classifiers
# -------------------
# [LABEL]:FAT ALBERT: Finding Answers in Large Texts using Semantic Similarity   Attention Layer based on BERT
# [PRED]:Machine based text comprehension
# -------------------
# [LABEL]:Multi-View Graph Representation Learning Beyond Homophily
# [PRED]:Multi-view Graph Representation Learning
# -------------------
# [LABEL]:GLIMMER: generalized late-interaction memory reranker
# [PRED]:Memory-augmentation in Language Models
# -------------------
# [LABEL]:An Improved Simulation Model for Pedestrian Crowd Evacuation
# [PRED]:A new method for pedestrian crowd evacuation based on various AI techniques
# -------------------
# [LABEL]:Semantics and pragmatics in actual software applications and in web   search engines: exploring innovations
# [PRED]:Generate a relevant title related to the use of the Semantic Web
# -------------------
# [LABEL]:Towards Arabic Multimodal Dataset for Sentiment Analysis
# [PRED]:Abstract: Multimodal Sentiment Analysis with Deep Learning-Based Models
# -------------------
# [LABEL]:Series Resonant Matrix Converter Topology for EV DC Fast Charging
# [PRED]:Generate a high-frequency DC link for EV DC Fast Charging
# -------------------
# [LABEL]:Improving Urban Mobility: using artificial intelligence and new   technologies to connect supply and demand
# [PRED]:Information and Communication Technologies for Intelligent Transportation Systems
# -------------------
# [LABEL]:NLQxform: A Language Model-based Question to SPARQL Transformer
# [PRED]:NHLQxform - Knowledge Graph Question Answering
# -------------------
# [LABEL]:A Reference Architecture and Modelling Principles for Architectural   Stability based on Self-Awareness: Case of Cloud Architectures
# [PRED]:Generate a reference architecture and model for stability in long-lived software
# -------------------
# [LABEL]:Constructing extremal triangle-free graphs using integer programming
# [PRED]:Generate an integer programming formulation for triangle-free extremal graphs
# -------------------
# [LABEL]:Multicommodity Flow in Polynomial Time
# [PRED]:Multicommodity flow problem in bipartite graphsGenerated Title:
# -------------------
# [LABEL]:A Survey of the Impact of Self-Supervised Pretraining for Diagnostic   Tasks with Radiological Images
# [PRED]:Self-supervised pretraining in X-ray, computed tomography, and ultrasound imaging
# -------------------
# [LABEL]:An Operator-Splitting Finite Element Method for the Numerical Solution   of Radiative Transfer Equation
# [PRED]:An operator-splitting finite element scheme for the time-dependent, high-dimensional radiative transfer equation
# -------------------
# [LABEL]:Enhancing CT Image synthesis from multi-modal MRI data based on a   multi-task neural network framework
# [PRED]:Generate a versatile multi-task neural network framework for medical imaging
# -------------------
# [LABEL]:Detecting semantic anomalies
# [PRED]:Generate a relevant title related to the use of out-of-distribution (OOD) detection
# -------------------
# [LABEL]:Cross-modal Attention Congruence Regularization for Vision-Language   Relation Alignment
# [PRED]:Figure 2: Cross-modal Attention Congruence Regularization in Multimodal Vision Language Models
# -------------------
# [LABEL]:Spatial-Temporal Graph Convolutional Networks for Sign Language   Recognition
# [PRED]:Spatial-Temporal Graph Convolutional Network to Sign Language Recognition
# -------------------
# [LABEL]:An extended polygonal finite element method for large deformation   fracture analysis
# [PRED]:Extended finite element method for large strain fracture for hyper-elastic materials
# -------------------
# [LABEL]:Learning Solving Procedure for Artificial Neural Network
# [PRED]:LSP Neural Network in an Artificial Neural Network
# -------------------
# [LABEL]:The Systematic Review-lution: A Manifesto to Promote Rigour and   Inclusivity in Research Synthesis
# [PRED]:A systematic review of human-computer interaction
# -------------------
# [LABEL]:Automated Detection of Congenital Heart Disease in Fetal Ultrasound   Screening
# [PRED]:Generate a pipeline for automated data curation and classification in fetal ultrasound
# -------------------
# [LABEL]:AutoPET Challenge: Combining nn-Unet with Swin UNETR Augmented by   Maximum Intensity Projection Classifier
# [PRED]:AutoPET: A Data Set for FDG-PETCT Tumor Segmentation
# -------------------
# [LABEL]:Numerical analysis of a singularly perturbed 4th order problem with a   shift term
# [PRED]:Generate a numerical method for one-dimensional singularly perturbed 4th order problem
# -------------------
# [LABEL]:Computation of Large-Genus Solutions of the Korteweg-de Vries Equation
# [PRED]:Generate a relevant title related to the Korteweg-de Vries equation when the genus is large
# -------------------
# [LABEL]:Stigmergy-based, Dual-Layer Coverage of Unknown Indoor Regions
# [PRED]:Generate a dual role concept for a swarm of simple, anonymous and autonomous mobile agents with local sensing capabilities
# -------------------
# [LABEL]:Quantum circuit synthesis of Bell and GHZ states using projective   simulation in the NISQ era
# [PRED]:Generate a relevant title related to quantum circuit synthesis and quantum circuit optimization techniques
# -------------------
# [LABEL]:A Framework for Combustion Chemistry Acceleration with DeepONets
# [PRED]:Chemistry Acceleration with Deep Operational Networks
# -------------------
# [LABEL]:Language Quantized AutoEncoders: Towards Unsupervised Text-Image   Alignment
# [PRED]:LQAE: Language-Quantized AutoEncoder for Multi-Task Image Classification
# -------------------
# [LABEL]:ASSERT: Anti-Spoofing with Squeeze-Excitation and Residual neTworks
# [PRED]:Anti-Spoofing with Squeeze-Excitation and Residual NeTworks
# -------------------
# [LABEL]:InceptionNeXt: When Inception Meets ConvNeXt
# [PRED]:Inception Depthwise Convolution for Large-Kernel-Based CNN Models
# -------------------
# [LABEL]:Gameplay experience in a gaze interaction game
# [PRED]:Viewing experience for gaze interaction games
# -------------------
# [LABEL]:Controller Synthesis for Discrete-Time Polynomial Systems via Occupation   Measures
# [PRED]:Nonlinear state feedback controllers for discrete-time polynomial dynamical systems
# -------------------
# [LABEL]:Cross-Modal Alignment Learning of Vision-Language Conceptual Systems
# [PRED]:Generate an aligned cross-modal representation learning method based on infants' word learning mechanisms
# -------------------
# [LABEL]:Mathematical meal models for simulation of human metabolism
# [PRED]:Generate a relevant title related to the mathematical model of the meal glucose rate of appearance in humans
# -------------------
# [LABEL]:Harbsafe-162. A Domain-Specific Data Set for the Intrinsic Evaluation of   Semantic Representations for Terminological Data
# [PRED]:Harbsafe-162: a domain-specific data set for evaluating distributional semantic models
# -------------------
# [LABEL]:Digital Health Discussion Through Articles Published Until the Year   2021: A Digital Topic Modeling Approach
# [PRED]:The Web of Science: Trends in Digital Health-related Articles
# -------------------
# [LABEL]:SUMMIT: Source-Free Adaptation of Uni-Modal Models to Multi-Modal   Targets
# [PRED]:Generate a relevant title related to the semantic segmentation problem
# -------------------
# [LABEL]:Model-Based Clustering of Time-Evolving Networks through Temporal   Exponential-Family Random Graph Models
# [PRED]:Generate a New Model-Based clustering Framework for Time-Evolving Networks
# -------------------
# [LABEL]:Towards Better Long-range Time Series Forecasting using Generative   Forecasting
# [PRED]:Generative Forecasting for Long-Range Time Series Forecasting
# -------------------
# [LABEL]:Unsupervised Feature Learning through Divergent Discriminative Feature   Accumulation
# [PRED]:divergent discriminative feature accumulation
# -------------------
# [LABEL]:Nonuniform Negative Sampling and Log Odds Correction with Rare Events   Data
# [PRED]:Generate a General inverse probability weighted (IPW) estimator for imbalanced data
# -------------------
# [LABEL]:Tilt Assembly: Algorithms for Micro-Factories That Build Objects with   Uniform External Forces
# [PRED]:Tilt Assembly Problem for Micro-Scale Objects in Two and Three Dimensions
# -------------------
# [LABEL]:HLO: Half-kernel Laplacian Operator for Surface Smoothing
# [PRED]:Half-kernel Laplacian Operator for Surface Denoising
# -------------------
# [LABEL]:Distribution Calibration for Regression
# [PRED]:Generate a Presentation Description of Multi-Output Gaussian Processes with Beta link function
# -------------------
# [LABEL]:Considerations for Ethical Speech Recognition Datasets
# [PRED]:Speech AI Technologies: A Case Study for Responsible AI
# -------------------
# [LABEL]:Dual GNNs: Graph Neural Network Learning with Limited Supervision
# [PRED]:Dual GNN Learning Framework for Semi-Supervised Node Classification
# -------------------
# [LABEL]:New mixed formulation and mesh dependency of finite elements based on   the consistent couple stress theory
# [PRED]:Generate a general finite element formulation based on the consistent couple stress theory
# -------------------
# [LABEL]:Self-Sustaining Multiple Access with Continual Deep Reinforcement   Learning for Dynamic Metaverse Applications
# [PRED]:Self-sustainability in multi-channel environments
# -------------------
# [LABEL]:Understanding Catastrophic Forgetting in Language Models via Implicit   Inference
# [PRED]:Conjugate Prompting for Learning From the Fine-Tuning Data Distribution
# -------------------
# [LABEL]:Information Retention in the Multi-platform Sharing of Science
# [PRED]:Generate a burst-based framework for examining online discussions about science over time
# -------------------
# [LABEL]:Corruption Risk in Contracting Markets: A Network Science Perspective
# [PRED]:Analysis of corruption risk in European Union Public Procurement Contracts
# -------------------
# [LABEL]:Exploring Security Commits in Python
# [PRED]:Security Commit Datasets in Python
# -------------------
# [LABEL]:Linguistic Markers of Influence in Informal Interactions
# [PRED]:Social Influence in Online Knitting Communities
# -------------------
# [LABEL]:Effective zero-dimensionality for computable metric spaces
# [PRED]:TTE
# -------------------
# [LABEL]:Continuous conditional generative adversarial networks for data-driven   solutions of poroelasticity with heterogeneous material properties
# [PRED]:Continuous CGAN for Time-Dependent Problems
# -------------------
# [LABEL]:Detecting lateral genetic material transfer
# [PRED]:Generate a relevant title related to the use of bioinformatical methods to detect lateral gene transfer between bacteria
# -------------------
# [LABEL]:Geographical Asynchronous Information Access for Distributed Systems
# [PRED]:GEOIA for Geo-Localized Geographical Information Systems
# -------------------
# [LABEL]:Real-time Human Detection in Fire Scenarios using Infrared and Thermal   Imaging Fusion
# [PRED]:Light Heating Chessboard for Human Detection in Smoke
# -------------------
# [LABEL]:Learning to Act with Affordance-Aware Multimodal Neural SLAM
# [PRED]:Affordance-aware Multimodal Neural SLAM
# -------------------
# [LABEL]:Convergence analysis of online algorithms for vector-valued kernel   regression
# [PRED]:Generate a relevant title related to the problem of approximating the regression function from noisy vector-valued data by an online learning algorithm
# -------------------
# [LABEL]:Average Case Analysis of Leaf-Centric Binary Tree Sources
# [PRED]:Generate a relevant title related to the average number of distinct fringe subtrees in random binary trees generated by leaf-centric binary tree sources
# -------------------
# [LABEL]:TENET: A Time-reversal Enhancement Network for Noise-robust ASR
# [PRED]:TENET: Time-reversal Enhancement NETwork for Noise-robust Automatic Speech Recognition
# -------------------
# [LABEL]:A General Framework for Robust G-Invariance in G-Equivariant Networks
# [PRED]:Generate a general method for achieving robust group-invariance in group-equivariant convolutional networks
# -------------------
# [LABEL]:Does MAML Only Work via Feature Re-use? A Data Centric Perspective
# [PRED]:Meta-Learning in Meta-Learning
# -------------------
# [LABEL]:Personalized Transformer for Explainable Recommendation
# [PRED]:PErsonalized Transformer for Explainable Recommendation
# -------------------
# [LABEL]:Automatic detection of multilevel communities: scalable and   resolution-limit-free
# [PRED]:Modularity-based Community Detection Based on a Scalable Community "Fitness Function"
# -------------------
# [LABEL]:Lifelong Personal Context Recognition
# [PRED]:Generate a relevant title related to the development of lifelong context recognition using machine learning
# -------------------
# [LABEL]:Randomized Cholesky QR factorizations
# [PRED]:Generate a randomized Cholesky QR factorization of a matrix $X$
# -------------------
# [LABEL]:Random access congestion control in DVB-RCS2 interactive satellite   terminals
# [PRED]:Random Access congestion control in DVB-RCS2
# -------------------
# [LABEL]:Key Phrase Classification in Complex Assignments
# [PRED]:in the case of key phrase classification
# -------------------
# [LABEL]:Multi-scale Attentive Image De-raining Networks via Neural Architecture   Search
# [PRED]:Multi-scale attentive neural architecture search for image deraining
# -------------------
