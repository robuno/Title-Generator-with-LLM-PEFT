# %%
import os
import pandas as pd

# %%
df_results = pd.read_csv('./bart_4000/dialog_test_results_1_4000.csv')
df_results.head()
# Out:
#    Unnamed: 0                                              label  \
# 0           0  List Decoding of Hermitian Codes using Groebne...
# 1           1  The Network Nullspace Property for Compressed ...
# 2           2  Task-Agnostic Online Reinforcement Learning wi...
# 3           3                        Where is the Edge of Chaos?
# 4           4  Denominator Bounds and Polynomial Solutions fo...
#
#                                           prediction
# 0  Generate a relevant title related to the given...
# 1  Generate a relevant title related to the given...
# 2  Generate a continuous online model-based reinf...
# 3  Generate a relevant title related to the given...
# 4  Generate a relevant title related to the given...

# %%
df_results['prediction'] = df_results['prediction'].str.replace('Generate a relevant title related to the given abstracte: ', '')
df_results.head()
# Out:
#    Unnamed: 0                                              label  \
# 0           0  List Decoding of Hermitian Codes using Groebne...
# 1           1  The Network Nullspace Property for Compressed ...
# 2           2  Task-Agnostic Online Reinforcement Learning wi...
# 3           3                        Where is the Edge of Chaos?
# 4           4  Denominator Bounds and Polynomial Solutions fo...
#
#                                           prediction
# 0   List decoding of Hermitian codes is reformula...
# 1                             Net nullspace property
# 2  Generate a continuous online model-based reinf...
# 3   The emergent regime in one-dimensional cellul...
# 4   We consider systems A\ell(t) y(q^\ell t) with...

# %%
for index, row in df_results.iterrows():
  print(f"[LABEL]:{row['label']}")
  print(f"[PRED]:{row['prediction']}")
  print('-'.join('' for x in range(20)))
# Out:
# [LABEL]:List Decoding of Hermitian Codes using Groebner Bases
# [PRED]: List decoding of Hermitian codes is reformulated to allow an efficient and simple algorithm for the interpolation step. The algorithm is developed using the theory of Groebner bases of modules. The computational complexity of the algorithm seems comparable to previously known algorithms achieving the same task,
# -------------------
# [LABEL]:The Network Nullspace Property for Compressed Sensing of Big Data over   Networks
# [PRED]: Net nullspace property
# -------------------
# [LABEL]:Task-Agnostic Online Reinforcement Learning with an Infinite Mixture of   Gaussian Processes
# [PRED]:Generate a continuous online model-based reinforcement learning approach for nonstationary tasks with unknown task boundaries
# -------------------
# [LABEL]:Where is the Edge of Chaos?
# [PRED]: The emergent regime in one-dimensional cellular automata and random Boolean networks
# -------------------
# ...
